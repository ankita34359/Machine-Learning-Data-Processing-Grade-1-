# %%
import pandas as pd
import numpy as np

# %%
print(pd)
# Out:
# <module 'pandas' from 'C:\\Users\\Lenovo\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_excel("grade_data.xlsx")
print(df)
# Out:
#          Name  StudyHour  Grade
# 0         Dan      10.00   50.0
# 1       Joann      11.50   50.0
# 2       Pedro       9.00   47.0
# 3       Rosie      16.00   97.0
# 4       Ethan       9.25   49.0
# 5       Vicky       1.00    3.0
# 6    Frederic      11.50   53.0
# 7      Jimmie       9.00   42.0
# 8      Rhonda       8.50   26.0
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0
# 12       Bill       8.00    NaN
# 13        Ted        NaN    NaN

# %% [markdown]
# Getting the first five data from dataset

# %%
df.head()
# Out:
#     Name  StudyHour  Grade
# 0    Dan      10.00   50.0
# 1  Joann      11.50   50.0
# 2  Pedro       9.00   47.0
# 3  Rosie      16.00   97.0
# 4  Ethan       9.25   49.0

# %% [markdown]
# Getting the size of data in form of rows and columns

# %%
df.shape
# Out:
# (14, 3)

# %% [markdown]
# Finding the Nan values

# %%
df.isna().sum()
# Out:
# Name         0
# StudyHour    1
# Grade        2
# dtype: int64

# %% [markdown]
# Getting the last five data from dataset

# %%
df.tail()
# Out:
#          Name  StudyHour  Grade
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0
# 12       Bill       8.00    NaN
# 13        Ted        NaN    NaN

# %% [markdown]
# Dropping the values

# %%
df.dropna(axis=0 , how="any").tail()
# Out:
#          Name  StudyHour  Grade
# 7      Jimmie       9.00   42.0
# 8      Rhonda       8.50   26.0
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0

# %%
df.dropna(axis=0 , how="all").tail()
# Out:
#          Name  StudyHour  Grade
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0
# 12       Bill       8.00    NaN
# 13        Ted        NaN    NaN

# %%
df.dropna(axis=1 , how="any").tail()
# Out:
#          Name
# 9    Giovanni
# 10  Francesca
# 11      Rajab
# 12       Bill
# 13        Ted

# %%
df.dropna(axis=1 , how="all").tail()
# Out:
#          Name  StudyHour  Grade
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0
# 12       Bill       8.00    NaN
# 13        Ted        NaN    NaN

# %% [markdown]
# Filling Nan Values

# %%
df["StudyHour"].mean()
# Out:
# 10.576923076923077

# %%
m = round(df["StudyHour"].mean(), 2)
m
# Out:
# 10.58

# %%
df["StudyHour"] = df["StudyHour"].fillna(m)
df
# Out:
#          Name  StudyHour  Grade
# 0         Dan      10.00   50.0
# 1       Joann      11.50   50.0
# 2       Pedro       9.00   47.0
# 3       Rosie      16.00   97.0
# 4       Ethan       9.25   49.0
# 5       Vicky       1.00    3.0
# 6    Frederic      11.50   53.0
# 7      Jimmie       9.00   42.0
# 8      Rhonda       8.50   26.0
# 9    Giovanni      14.50   74.0
# 10  Francesca      15.50   82.0
# 11      Rajab      13.75   62.0
# 12       Bill       8.00    NaN
# 13        Ted      10.58    NaN

# %%
df["Grade"].mean()
# Out:
# 52.916666666666664

# %%
n = round(df["Grade"].mean(), 2)
n
# Out:
# 52.92

# %%
df["Grade"] = df["Grade"].fillna(n)
df
# Out:
#          Name  StudyHour  Grade
# 0         Dan      10.00  50.00
# 1       Joann      11.50  50.00
# 2       Pedro       9.00  47.00
# 3       Rosie      16.00  97.00
# 4       Ethan       9.25  49.00
# 5       Vicky       1.00   3.00
# 6    Frederic      11.50  53.00
# 7      Jimmie       9.00  42.00
# 8      Rhonda       8.50  26.00
# 9    Giovanni      14.50  74.00
# 10  Francesca      15.50  82.00
# 11      Rajab      13.75  62.00
# 12       Bill       8.00  52.92
# 13        Ted      10.58  52.92

# %%
df.isna().sum()
# Out:
# Name         0
# StudyHour    0
# Grade        0
# dtype: int64

# %% [markdown]
# Encoding of the categorical data

# %%
df = pd.read_csv("titanic.csv")
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 1: Using Map

# %%
df['Sex'] = df['Sex'].map({"male":0, "female":1})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %% [markdown]
# 2: Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']=LabelEncoder().fit_transform(df['Sex'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'] = LabelEncoder().fit_transform(df['Embarked'])

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   NaN      0      0
# ...

# %% [markdown]
# Delete the columns

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin
# 0         0       3    1  22.0      1      0   7.2500   NaN
# 1         1       1    0  38.0      1      0  71.2833   C85
# 2         1       3    0  26.0      0      0   7.9250   NaN
# 3         1       1    0  35.0      1      0  53.1000  C123
# 4         0       3    1  35.0      0      0   8.0500   NaN

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         2
# 1          PC 17599  71.2833   C85         0
# 2  STON/O2. 3101282   7.9250   NaN         2
# 3            113803  53.1000  C123         2
# 4            373450   8.0500   NaN         2

# %%
df = df.drop(columns=["Embarked"])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin
# 0         0       3    1  22.0      1      0   7.2500   NaN
# 1         1       1    0  38.0      1      0  71.2833   C85
# 2         1       3    0  26.0      0      0   7.9250   NaN
# 3         1       1    0  35.0      1      0  53.1000  C123
# 4         0       3    1  35.0      0      0   8.0500   NaN

# %%
df = df.drop(columns=["PassengerId", "Name", "Ticket"])

# %% [markdown]
# Preprocessing Of Numerical Data:

# %% [markdown]
# Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Making copy of df data set

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin
# 0         0       3    1  22.0      1      0   7.2500   NaN
# 1         1       1    0  38.0      1      0  71.2833   C85
# 2         1       3    0  26.0      0      0   7.9250   NaN
# 3         1       1    0  35.0      1      0  53.1000  C123
# 4         0       3    1  35.0      0      0   8.0500   NaN

# %%
df2["Age"] = MinMaxScaler().fit_transform(df2[["Age"]])

# %%
df2.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch     Fare Cabin
# 0         0       3    1  0.271174      1      0   7.2500   NaN
# 1         1       1    0  0.472229      1      0  71.2833   C85
# 2         1       3    0  0.321438      0      0   7.9250   NaN
# 3         1       1    0  0.434531      1      0  53.1000  C123
# 4         0       3    1  0.434531      0      0   8.0500   NaN

# %%
df2["Fare"] = MinMaxScaler().fit_transform(df2[["Fare"]])

# %%
df2.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch      Fare Cabin
# 0         0       3    1  0.271174      1      0  0.014151   NaN
# 1         1       1    0  0.472229      1      0  0.139136   C85
# 2         1       3    0  0.321438      0      0  0.015469   NaN
# 3         1       1    0  0.434531      1      0  0.103644  C123
# 4         0       3    1  0.434531      0      0  0.015713   NaN
